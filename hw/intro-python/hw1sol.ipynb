# %% [markdown]
# **Problem 1**: Write a program to determine the prime factors of a user supplied number.  The script shoudl contain a function *prime_factors* that takes a single argument that is an integer.  It should return a sorted list of the prime factors.

# %%
import math

def prime_factors(n):
    ret = []
    try:
        n = int(n) ## try to cast to int in case we're given a different type, e.g. float, string
    except:
        print('Invalid input.  Please enter a positive integer.')
        return ret
    if n < 2: return ret
    while n%2 == 0: ## first find all factors of 2 by which n is divisible
        ret.append(2)
        n /= 2
    for i in range(3,math.ceil(math.sqrt(n))+1,2): ## now check all odd numbers up to the sqrt(n)
        while n%i == 0:
            ret.append(i)
            n /= i
    if n > 2: ret.append(int(n))
    return ret

# %% [markdown]
# Now let's run some tests to check that the function works as expected.

# %%
test_vals = [-4, 0, 2.2, '54', 'abc', 1230523]
correct_factors = [[],[],[2],[2,3,3,3],[],[7,23,7643]]
check = []
for index,val in enumerate(test_vals):
    ret = prime_factors(val)
    check.append(True if ret == correct_factors[index] else False)
    
for (a,b) in zip(test_vals,check):
    print('{}: {}'.format(a,b))
# Out:
# Invalid input.  Please enter a positive integer.
# -4: True
# 0: True
# 2.2: True
# 54: True
# abc: True
# 1230523: True

# %% [markdown]
# **Problem 2**: Many websites require users to input a username and password to register.  Write a function to generate a random password that meets the following criterita:
#
# (a) At least one lower case letter <br>
# (b) At least one upper case letter <br>
# (c) At least one number <br>
# (d) At least on character that is not a letter or a number <br>
# (e) Whitespace characters are not allowed <br>
# (f) At least 6 characters long <br>
# (g) No more than 20 characters long <br>
#
# The function should be called *generate_password*.  It shoudl take no arguments and return a string with the randomly generated password.  You should also write a second function called *check_password*, which takes a single argument that is a proposed password and returns a boolean indicating whether or not the password is valid.

# %%
import string
import random

##
## generate random password meeting the following criteria:
## 1. at least one lower case letter
## 2. at least one upper case letter
## 3. at least one digit
## 4. at least one non-letter, non-digit character
## 5. no whitespace characters
## 6. at least 6 characters and no more than 20 characters
##
## the logic used is:
## - generate random number on [6,20], rand_len, for the length of the password
## - generate a random character from each of the categories 1-4 above
## - generate rand_len-4 random characters from any of the categories 1-4 above
##
## randomnize order of generated characters and return password
##
def generate_password():
    inputs = [string.ascii_lowercase,string.ascii_uppercase,string.digits,string.punctuation]
    min_chars = 6
    max_chars = 20
    ntokens = random.randint(min_chars,max_chars) ## password length
    tokens = [random.choice(val) for val in inputs] ## get a random value of each of the 4 types of required characrters
    ntokens -= len(tokens)
    while ntokens > 0: ## now get all the rest of the random characters until len(tokens)=ntokens
        tokens.append(random.choice(''.join(inputs)))
        ntokens -= 1
    random.shuffle(tokens) ## randomnize the order
    return ''.join(tokens)

# %%
##
## check if a string (password) meets the following criteria:
## 1. at least one lower case letter
## 2. at least one upper case letter
## 3. at least one digit
## 4. at least one non-letter, non-digit character
## 5. no whitespace characters
## 6. at least 6 characters and no more than 20 characters
##
def check_password(passwd,verbose=False):
    min_chars = 6
    max_chars = 20
    ## check length of password
    if len(passwd) < min_chars:
        if verbose: print('password %s is too short.  it contains %d characters' % (passwd, len(passwd)))
        return False
    if len(passwd) > max_chars:
        if verbose: print('password %s is too long.  it contains %d characters' % (passwd, len(passwd)))
        return False
    inputs = {string.ascii_lowercase:'lower case letter',string.ascii_uppercase:'upper case letter',string.digits:'digit',string.punctuation:'non-letter, non-digit character'}
    rets = {}
    ## check which characters in categories 1-4 above are in string and record category
    for chars in inputs.keys():
        rets[chars] = False
        for char in chars:
            if char in passwd:
                rets[chars] = True
                break
    ## just keep track of the categories missing
    good_keys = []
    for (key,value) in rets.items():
        if value: good_keys.append(key)
    for key in good_keys: del rets[key]
    if len(rets) == 0:
        return True
    else:
        if verbose: print('password {} is not good, it is missing: '.format(passwd),)
        for index,key in enumerate(rets.keys()):
            if index < len(rets.values())-1:
                if verbose: print('a %s, ' % (inputs[key]),)
            else:
                if verbose: print('a %s' % (inputs[key]))
        return False

# %% [markdown]
# Run some tests to check if the functions behave as expected.

# %%
##
## generate 1K passwords and check with reference check_password function
##
bad_passwds = []
nexceptions_generate = 0
for i in range(10**3):
    try:
        passwd = generate_password() ## generate password
        if not check_password(passwd,True): ## check that it is good
            bad_passwds.append(passwd)
    except:
        nexceptions_generate += 1
        if verbose:
            print('Exception found calling submitted generate_password() function.')
            
print('Found {} bad passwords.'.format(len(bad_passwds)))
# Out:
# Found 0 bad passwords.

# %% [markdown]
# The above doesn't really test what we want, it only tests that the *generate_password* and *check_password* functions are self consistent.  Let's generate some **incorrect** passwords and see how the *check_password* function performs.

# %%
##
## second: generate 1K incorrect passwords
##
tests = ['all_upper','all_lower','no_numbers','no_special','too_short','too_long']
failed_checks_bad = {}
for i in range(10**3):
    try:
        passwd = generate_password()
        test = tests[i%len(tests)]
        if test == 'all_upper':
            if check_password(passwd.upper()):
                if test not in failed_checks_bad:
                    failed_checks_bad[test] = []
                failed_checks_bad[test].append(passwd.upper())
        elif test == 'all_lower':
            if check_password(passwd.lower()):
                if test not in failed_checks_bad:
                    failed_checks_bad[test] = []
                failed_checks_bad[test].append(passwd.lower())
        elif test == 'no_numbers':
            passwd = ''.join([i for i in passwd if not i.isdigit()])
            if check_password(passwd):
                if test not in failed_checks_bad:
                    failed_checks_bad[test] = []
                failed_checks_bad[test].append(passwd)
        elif test == 'no_special':
            passwd = ''.join([i for i in passwd if i not in string.punctuation])
            if check_password(passwd):
                if test not in failed_checks_bad:
                    failed_checks_bad[test] = []
                failed_checks_bad[test].append(passwd)
        elif test == 'too_short':
            if check_password(passwd[:5]):
                if test not in failed_checks_bad:
                    failed_checks_bad[test] = []
                failed_checks_bad[test].append(passwd[:5])
        elif test == 'too long':
            passwd = passwd + ''.join('x' for i in range(21-len(passwd)))
            if check_password(passwd):
                if test not in failed_checks_bad:
                    failed_checks_bad[test] = []
                failed_checks_bad[test].append(passwd)
    except:
        nexceptions_check += 1
        if verbose:
            print('Exception found calling submitted check_password() function.')
            
print('check_password failed {} categories.'.format(len(failed_checks_bad)))
for key,value in failed_checks_bad:
    if len(value) == 0: continue
    print('check_password failed {} times for category {}'.format(len(value),key))
# Out:
# check_password failed 0 categories.

# %% [markdown]
# **Problem 3**: Write a function called *get_directory_contents*.  The function should take two arguments, the first a path and the second a boolean that has default value <u>False</u>.  The function should run the shell command */bin/ls* on the user specified path, return the contents of the directory as a list, and if the boolean is True, print a comma-separated list of the contents.  Write a second function *get_list_of_files*.  This function should take three arguments: the first a path, the second an (optional) file extension that should default to any extension, and an optional third boolean argument that has the default value <u>False</u>.  The function should return a list of all files in the input path that match the input file extension.  If the boolean input is set to <u>True</u>, it should also print a formatted list to the screen.  You may find the python **os** or **subprocess** modules helpful.  Something like this could be useful because the output of the shell command would then be available to python for further processing.  Use the functions you've written to determine the number of perl scripts in the path */usr*, i.e. files that end in *.pl*.

# %%
import os

##
## Method 1: use os module
##
def get_directory_contents_os(path, formatted=False):
    stream = os.popen('/bin/ls {}'.format(path))
    if formatted:
        output = stream.readlines()
        print(' '.join(str(x.strip()) for x in output))
    else:
        print(stream.read())

# %%
get_directory_contents_os('/usr')
print('')
get_directory_contents_os('/usr',True)
# Out:
# X11
# X11R6
# bin
# lib
# libexec
# local
# sbin
# share
# standalone
#
#
# X11 X11R6 bin lib libexec local sbin share standalone

# %%
import subprocess

##
## Method 2: use subprocess module
##
def get_directory_contents_sub(path, formatted=False):
    process = subprocess.Popen(['/bin/ls','/usr'],stdout=subprocess.PIPE,stderr=subprocess.PIPE)
    stdout,stderr = process.communicate()
    if formatted:
        print(' '.join(x.decode('utf-8') for x in stdout.split())) ## process.communicate() returns a byte string, need to decode before printing to decode before printing
    else:
        print(stdout.decode('utf-8'))

# %%
get_directory_contents_sub('/usr')
print('')
get_directory_contents_sub('/usr',True)
# Out:
# X11
# X11R6
# bin
# lib
# libexec
# local
# sbin
# share
# standalone
#
#
# X11 X11R6 bin lib libexec local sbin share standalone

# %%
##
## now let's use the subprocess module to find all perl (file_name.pl) files in the 'path'
##
def get_list_of_files(path,ext='',dump=False):    
    process = subprocess.Popen(['find',path,'-type','f'],stdout=subprocess.PIPE,stderr=subprocess.PIPE)
    stdout,stderr = process.communicate()
    if not ext:
        lof = [f.decode('utf-8') for f in stdout.split()]
        if dump:
            print('\n'.join(lof))
        return lof
    else:
        lof = [f.decode('utf-8') for f in stdout.split() if f.decode('utf-8').endswith('.{}'.format(ext))]
        if dump:
            print('\n'.join(lof))
        return lof

# %%
path = '/usr'
ext = 'pl'
lf = get_list_of_files(path,ext)
print('Found {} .{} files in path {}.'.format(len(lf),ext,path))
get_list_of_files(path,ext,True)
print('Found {} .{} files in path {}.'.format(len(lf),ext,path))
# Out:
# Found 369 .pl files in path /usr.
# /usr/bin/binhex5.18.pl
# /usr/bin/stty.pl
# /usr/bin/binhex5.28.pl
# /usr/bin/scandeps5.30.pl
# /usr/bin/scandeps.pl
# /usr/bin/debinhex5.30.pl
# /usr/bin/stty5.18.pl
# /usr/bin/par5.30.pl
# /usr/bin/xgettext5.30.pl
# /usr/bin/scandeps5.28.pl
# /usr/bin/binhex5.30.pl
# /usr/bin/scandeps5.18.pl
# /usr/bin/xgettext.pl
# /usr/bin/binhex.pl
# /usr/bin/debinhex5.28.pl
# /usr/bin/debinhex5.18.pl
# /usr/bin/xgettext5.28.pl
# /usr/bin/par5.28.pl
# /usr/bin/xgettext5.18.pl
# /usr/bin/debinhex.pl
# /usr/bin/par.pl
# /usr/libexec/postfix/greylist.pl
# /usr/libexec/emlog.pl
# /usr/local/etc/openssl@1.1/misc/tsget.pl
# /usr/local/etc/openssl@1.1/misc/CA.pl
# /usr/local/etc/openssl/misc/CA.pl
# /usr/local/Cellar/highlight/3.55/share/doc/highlight/extras/swig/testmod.pl
# /usr/local/Cellar/highlight/3.55/share/doc/highlight/extras/web_plugins/movabletype/highlight.pl
# /usr/local/Cellar/qt/5.10.1/bin/fixqt4headers.pl
# /usr/local/Cellar/qt/5.10.1/bin/syncqt.pl
# /usr/local/Cellar/qt/5.10.1/mkspecs/features/data/unix/findclasslist.pl
# /usr/local/Cellar/open-mpi/4.0.3/bin/aggregate_profile.pl
# /usr/local/Cellar/open-mpi/4.0.3/bin/profile2mat.pl
# /usr/local/Cellar/gettext/0.20.2_1/share/doc/gettext/examples/hello-c++-kde/admin/config.pl
# /usr/local/Cellar/gettext/0.20.2_1/share/doc/gettext/examples/hello-c++-kde/admin/cvs-clean.pl
# /usr/local/Cellar/gettext/0.20.2_1/share/doc/gettext/examples/hello-c++-kde/admin/conf.change.pl
# /usr/local/Cellar/gettext/0.19.8.1/share/doc/gettext/examples/hello-c++-kde/admin/config.pl
# /usr/local/Cellar/gettext/0.19.8.1/share/doc/gettext/examples/hello-c++-kde/admin/cvs-clean.pl
# /usr/local/Cellar/gettext/0.19.8.1/share/doc/gettext/examples/hello-c++-kde/admin/conf.change.pl
# /usr/local/Cellar/openssl@1.1/1.1.1g/.bottle/etc/openssl@1.1/misc/tsget.pl
# /usr/local/Cellar/openssl@1.1/1.1.1g/.bottle/etc/openssl@1.1/misc/CA.pl
# /usr/local/Cellar/openssl@1.1/1.1.1d/.bottle/etc/openssl@1.1/misc/tsget.pl
# /usr/local/Cellar/openssl@1.1/1.1.1d/.bottle/etc/openssl@1.1/misc/CA.pl
# /usr/local/Cellar/openssl/1.0.2r/.bottle/etc/openssl/misc/CA.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/koma-script/doc/bin/genhtmlidx.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/koma-script/doc/bin/genindex.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/latex-tds/build.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/latex-tds/lib/adjust_checksum.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/latex-tds/lib/ziptimetree.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/hyperref/psdmapshortnames.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/cjk/utils/subfonts/uni2sfd.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/cjk/utils/subfonts/makefdx.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/cjk/utils/subfonts/clonevf.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/cjk/utils/subfonts/sfd2uni.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/cjk/utils/subfonts/hlatex2agl.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/cjk/contrib/wadalab/fixwada2.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/cjk/contrib/wadalab/makeuniwada.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/otibet/tibetan.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/feynmf/feynmf.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/mathpazo/cmex10.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/mathpazo/cmr10.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/mathpazo/cmmi10.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/mathpazo/fplmb.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/mathpazo/cmbx10.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/mathpazo/pazofnst/cmex10.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/mathpazo/pazofnst/cmr10.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/mathpazo/pazofnst/cmmi10.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/mathpazo/pazofnst/cmbx10.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/mathpazo/pazofnst/cmbsy10.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/mathpazo/pazofnst/cmsy10.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/mathpazo/pazofnst/cmmib10.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/mathpazo/cmbsy10.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/mathpazo/fplmbb.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/mathpazo/cmsy10.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/mathpazo/cmmib10.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/mathpazo/fplmri.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/mathpazo/fplmbi.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/mathpazo/fplmr.pl
# /usr/local/texlive/2017/texmf-dist/source/latex/hyper/dvi2pdf.pl
# /usr/local/texlive/2017/texmf-dist/source/luatex/luatexja/tool/ltj-unicode-ccfix_make2.pl
# /usr/local/texlive/2017/texmf-dist/source/xelatex/arabxetex/makemaps.pl
# /usr/local/texlive/2017/texmf-dist/source/support/bibtexperllibs/LaTeX-ToUnicode/script/convert.pl
# /usr/local/texlive/2017/texmf-dist/source/generic/hyph-utf8/contributed/make-exhyph.pl
# /usr/local/texlive/2017/texmf-dist/source/generic/hyphenex/hyphenex.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf/script/mkvpkana.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf/script/mktfm.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf/script/mkutfvf.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf/script/mkjp04tfmvf.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf/script/mkmlcidvf.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf/script/mkcidofm.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf/script/mkaltutfvf.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf/script/mkcidvf.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf/script/mkpropofm.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf/script/mkpkana.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf/basepl/base2-h.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf/basepl/base-v.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf/basepl/brsg-v.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf/basepl/brsg-h.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf/basepl/base-h.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf/basepl/base3-v.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf/basepl/base0-h.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf/basepl/base2-v.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/burmese/birm.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf-uptex/script/umkvpkana.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf-uptex/script/umkpkana.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf-uptex/script/mkutf32list.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf-uptex/script/mkutfvf_sp.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf-uptex/script/mktfm_sp.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf-uptex/basepl/ubase-h.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf-uptex/basepl/ubrsg-h.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf-uptex/basepl/ubrsg-v.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/japanese-otf-uptex/basepl/ubase-v.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/blacklettert1/ygoth.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/blacklettert1/ecbx1000.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/blacklettert1/yfrak.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/blacklettert1/cmr10.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/blacklettert1/ecrm0700.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/blacklettert1/cmu10.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/blacklettert1/cmmi10.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/blacklettert1/cmbx10.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/blacklettert1/ecrm1000.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/blacklettert1/cmr7.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/blacklettert1/cmbsy10.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/blacklettert1/cmsy10.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/blacklettert1/cmmib10.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/blacklettert1/yswab.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/uptex-fonts/upjisr-v.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/uptex-fonts/uprml-h-hk.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/uptex-fonts/uprml-h.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/uptex-fonts/upjisr-h.pl
# /usr/local/texlive/2017/texmf-dist/source/fonts/uptex-fonts/upjisr-h-hk.pl
# /usr/local/texlive/2017/texmf-dist/scripts/chktex/deweb.pl
# /usr/local/texlive/2017/texmf-dist/scripts/sty2dtx/sty2dtx.pl
# /usr/local/texlive/2017/texmf-dist/scripts/context/perl/makempy.pl
# /usr/local/texlive/2017/texmf-dist/scripts/context/perl/texfind.pl
# /usr/local/texlive/2017/texmf-dist/scripts/context/perl/texfont.pl
# /usr/local/texlive/2017/texmf-dist/scripts/context/perl/mptopdf.pl
# /usr/local/texlive/2017/texmf-dist/scripts/context/perl/pdftrimwhite.pl
# /usr/local/texlive/2017/texmf-dist/scripts/texdoctk/texdoctk.pl
# /usr/local/texlive/2017/texmf-dist/scripts/tex4ht/htmove.pl
# /usr/local/texlive/2017/texmf-dist/scripts/tex4ht/mk4ht.pl
# /usr/local/texlive/2017/texmf-dist/scripts/tex4ht/htcopy.pl
# /usr/local/texlive/2017/texmf-dist/scripts/oberdiek/pdfatfi.pl
# /usr/local/texlive/2017/texmf-dist/scripts/latexmk/latexmk.pl
# /usr/local/texlive/2017/texmf-dist/scripts/pst2pdf/pst2pdf.pl
# /usr/local/texlive/2017/texmf-dist/scripts/mathspic/mathspic.pl
# /usr/local/texlive/2017/texmf-dist/scripts/perltex/perltex.pl
# /usr/local/texlive/2017/texmf-dist/scripts/cjk-gs-integrate/cjk-gs-integrate.pl
# /usr/local/texlive/2017/texmf-dist/scripts/makedtx/makedtx.pl
# /usr/local/texlive/2017/texmf-dist/scripts/multibibliography/multibibliography.pl
# /usr/local/texlive/2017/texmf-dist/scripts/crossrefware/bibdoiadd.pl
# /usr/local/texlive/2017/texmf-dist/scripts/crossrefware/bibmradd.pl
# /usr/local/texlive/2017/texmf-dist/scripts/crossrefware/bbl2bib.pl
# /usr/local/texlive/2017/texmf-dist/scripts/crossrefware/bibzbladd.pl
# /usr/local/texlive/2017/texmf-dist/scripts/crossrefware/ltx2crossrefxml.pl
# /usr/local/texlive/2017/texmf-dist/scripts/mkjobtexmf/mkjobtexmf.pl
# /usr/local/texlive/2017/texmf-dist/scripts/ps2eps/ps2eps.pl
# /usr/local/texlive/2017/texmf-dist/scripts/dosepsbin/dosepsbin.pl
# /usr/local/texlive/2017/texmf-dist/scripts/a2ping/a2ping.pl
# /usr/local/texlive/2017/texmf-dist/scripts/thumbpdf/thumbpdf.pl
# /usr/local/texlive/2017/texmf-dist/scripts/pkfix/pkfix.pl
# /usr/local/texlive/2017/texmf-dist/scripts/texcount/texcount.pl
# /usr/local/texlive/2017/texmf-dist/scripts/svn-multi/svn-multi.pl
# /usr/local/texlive/2017/texmf-dist/scripts/fragmaster/fragmaster.pl
# /usr/local/texlive/2017/texmf-dist/scripts/pax/pdfannotextractor.pl
# /usr/local/texlive/2017/texmf-dist/scripts/texdef/texdef.pl
# /usr/local/texlive/2017/texmf-dist/scripts/shipunov/biokey2html2.pl
# /usr/local/texlive/2017/texmf-dist/scripts/shipunov/biokey2html3.pl
# /usr/local/texlive/2017/texmf-dist/scripts/shipunov/biokey2html1.pl
# /usr/local/texlive/2017/texmf-dist/scripts/mycv/mycv_split_contents.pl
# /usr/local/texlive/2017/texmf-dist/scripts/kotex-utils/ttf2kotexfont.pl
# /usr/local/texlive/2017/texmf-dist/scripts/kotex-utils/komkindex.pl
# /usr/local/texlive/2017/texmf-dist/scripts/kotex-utils/jamo-normalize.pl
# /usr/local/texlive/2017/texmf-dist/scripts/latexindent/latexindent.pl
# /usr/local/texlive/2017/texmf-dist/scripts/xindy/texindy.pl
# /usr/local/texlive/2017/texmf-dist/scripts/xindy/xindy.pl
# /usr/local/texlive/2017/texmf-dist/scripts/splitindex/splitindex.pl
# /usr/local/texlive/2017/texmf-dist/scripts/psutils/includeres.pl
# /usr/local/texlive/2017/texmf-dist/scripts/psutils/extractres.pl
# /usr/local/texlive/2017/texmf-dist/scripts/psutils/psjoin.pl
# /usr/local/texlive/2017/texmf-dist/scripts/srcredact/srcredact.pl
# /usr/local/texlive/2017/texmf-dist/scripts/ptex-fontmaps/kanji-fontmap-creator.pl
# /usr/local/texlive/2017/texmf-dist/scripts/ptex-fontmaps/kanji-config-updmap.pl
# /usr/local/texlive/2017/texmf-dist/scripts/ulqda/ulqda.pl
# /usr/local/texlive/2017/texmf-dist/scripts/rubik/rubikrotation.pl
# /usr/local/texlive/2017/texmf-dist/scripts/latexdiff/latexrevise.pl
# /usr/local/texlive/2017/texmf-dist/scripts/latexdiff/latexdiff-vc.pl
# /usr/local/texlive/2017/texmf-dist/scripts/latexdiff/latexdiff.pl
# /usr/local/texlive/2017/texmf-dist/scripts/mf2pt1/mf2pt1.pl
# /usr/local/texlive/2017/texmf-dist/scripts/pdflatexpicscale/pdflatexpicscale.pl
# /usr/local/texlive/2017/texmf-dist/scripts/vpe/vpe.pl
# /usr/local/texlive/2017/texmf-dist/scripts/ltximg/ltximg.pl
# /usr/local/texlive/2017/texmf-dist/scripts/epstopdf/epstopdf.pl
# /usr/local/texlive/2017/texmf-dist/scripts/pedigree-perl/pedigree.pl
# /usr/local/texlive/2017/texmf-dist/scripts/ctanupload/ctanupload.pl
# /usr/local/texlive/2017/texmf-dist/scripts/texlive/tlmgrgui.pl
# /usr/local/texlive/2017/texmf-dist/scripts/texlive/tlmgr.pl
# /usr/local/texlive/2017/texmf-dist/scripts/texlive/uninstall-win32.pl
# /usr/local/texlive/2017/texmf-dist/scripts/texlive/e2pall.pl
# /usr/local/texlive/2017/texmf-dist/scripts/texlive/mktexlsr.pl
# /usr/local/texlive/2017/texmf-dist/scripts/texlive/updmap.pl
# /usr/local/texlive/2017/texmf-dist/scripts/texlive/fmtutil.pl
# /usr/local/texlive/2017/texmf-dist/scripts/texfot/texfot.pl
# /usr/local/texlive/2017/texmf-dist/scripts/pdfcrop/pdfcrop.pl
# /usr/local/texlive/2017/texmf-dist/doc/uptex/uptex-base/samples/check_enc.pl
# /usr/local/texlive/2017/texmf-dist/doc/metapost/dviincl/README.pl
# /usr/local/texlive/2017/texmf-dist/doc/metapost/metapost-examples/mp2html.pl
# /usr/local/texlive/2017/texmf-dist/doc/pdftex/manual/syntaxform.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/przechlewski-book/README.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/confproc/example/generateswitch.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/confproc/generateswitch.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/examplep/wrfiles.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/lshort-mongol/fixdate.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/nmbib/nmbibtex.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/biblatex-gb7714-2015/gb7714texttobib.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/plweb/sample.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/ibycus-babel/ibyhyph.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/aomart/fullref.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/mycv/checksum.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/cjk/doc/pdfhowto/examples/gen-map.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/cjk/texlive/bin-cjkutils.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/cjk/texlive/cjk.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/cjk/texlive/garuda-c90.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/cjk/texlive/cjk-build.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/cjk/texlive/norasi-c90.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/cjk/texlive/dnp.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/cjk/texlive/c90.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/latex-web-companion/ch7/inv1html.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/latex-web-companion/ch7/test-SGMLS.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/latex-web-companion/ch7/sgmlspl.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/latex-web-companion/ch7/skel.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/latex-web-companion/ch7/inv2html.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/latex-web-companion/ch7/inv2lat.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/latex-web-companion/ch3/myinit.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/register/reg_list.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/lshort-italian/fixdate.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/barcodes/codean.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/montex/cyrename.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/montex/mkmlsmf.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/ucs/makeunidef.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/ucs/latexout.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/ucs/discovermacro.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/apprends-latex/exemples/beamer-themes.pl
# /usr/local/texlive/2017/texmf-dist/doc/latex/apprends-latex/exemples/polices.pl
# /usr/local/texlive/2017/texmf-dist/doc/xelatex/persian-bib/gen_pdf.pl
# /usr/local/texlive/2017/texmf-dist/doc/support/gustprog/porzadki.pl
# /usr/local/texlive/2017/texmf-dist/doc/support/dosepsbin/version.pl
# /usr/local/texlive/2017/texmf-dist/doc/support/dosepsbin/clean-case.pl
# /usr/local/texlive/2017/texmf-dist/doc/generic/mkjobtexmf/version.pl
# /usr/local/texlive/2017/texmf-dist/doc/generic/mkjobtexmf/clean-case.pl
# /usr/local/texlive/2017/texmf-dist/doc/generic/t2/make-enc.pl
# /usr/local/texlive/2017/texmf-dist/doc/generic/pst-geo/pst-geo-compress.pl
# /usr/local/texlive/2017/texmf-dist/doc/generic/pst-geo/pst-geo-decompress.pl
# /usr/local/texlive/2017/texmf-dist/doc/generic/pst-mirror/createEPS/scripts/filtre.pl
# /usr/local/texlive/2017/texmf-dist/doc/fonts/yannisgr/rgrsc10.pl
# /usr/local/texlive/2017/texmf-dist/doc/fonts/dad/dad-to-utf8.pl
# /usr/local/texlive/2017/texmf-dist/doc/fonts/dad/utf8-to-dad.pl
# /usr/local/texlive/2017/texmf-dist/doc/fonts/dad/make-dad-font.pl
# /usr/local/texlive/2017/texmf-dist/doc/fonts/zhmetrics-uptex/upzhm-v.pl
# /usr/local/texlive/2017/texmf-dist/doc/fonts/zhmetrics-uptex/upzhm-h.pl
# /usr/local/texlive/2017/texmf-dist/doc/fonts/gnu-freefont/tools/test/MES-Conformance/mes-list-expand.pl
# /usr/local/texlive/2017/texmf-dist/doc/fonts/gnu-freefont/tools/test/MES-Conformance/CheckConformance.pl
# /usr/local/texlive/2017/texmf-dist/doc/fonts/gnu-freefont/tools/utility/KerningNumerals.pl
# /usr/local/texlive/2017/texmf-dist/doc/texlive/texlive-en/archive/texlive.pl
# /usr/local/texlive/2017/texmf-dist/doc/texlive/texlive-en/archive/split.pl
# /usr/local/texlive/2017/texmf-dist/doc/texlive/texlive-en/archive/mod.pl
# /usr/local/texlive/2017/texmf-dist/doc/texlive/texlive-en/archive/l.pl
# /usr/local/texlive/2017/texmf-dist/doc/texlive/texlive-en/archive/status.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/goth7.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/min6.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/tmin8.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/min7.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/tgoth10.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/tmin9.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/tgoth5.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/goth6.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/min8.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/tmin6.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/goth9.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/goth8.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/tmin10.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/min9.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/tmin7.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/goth10.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/tgoth8.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/min10.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/tmin5.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/tgoth9.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/goth5.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/tgoth6.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/tgoth7.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/standard/min5.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/nmin-ngoth/ngoth9.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/nmin-ngoth/nmin9.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/nmin-ngoth/nmin8.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/nmin-ngoth/ngoth8.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/nmin-ngoth/nmin7.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/nmin-ngoth/ngoth7.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/nmin-ngoth/ngoth6.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/nmin-ngoth/nmin6.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/nmin-ngoth/ngoth5.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/nmin-ngoth/nmin5.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/nmin-ngoth/ngoth10.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/nmin-ngoth/nmin10.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/jis/jisn-v.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/jis/jis-v.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/jis/jis.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/ptex-fonts/jis/jisn.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/ot2-stixgeneral-italic.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/ot1-stixgeneral-bolditalic.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathcal.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathrm.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/ot1-stixgeneral-bold.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/ot1-stixgeneral.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/ts1-stixgeneral-italic.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/ts1-stixgeneral.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathrm-bold.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathtt.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathit-bold.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/ot2-stixgeneral-bold.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-extra1.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathsf-bold.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathbbit-bold.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathsf.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathscr.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/ot2-stixgeneral.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathbb.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/t1-stixgeneral-italic.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathfrak.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathbb-bold.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/t1-stixgeneral-bolditalic.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/t1-stixgeneral-bold.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-extra2-bold.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathsfit.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathex.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathex-bold.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathsfit-bold.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/ot2-stixgeneral-bolditalic.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathtt-bold.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/ot1-stixgeneral-italic.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/ts1-stixgeneral-bold.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-extra3-bold.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathscr-bold.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathfrak-bold.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathbbit.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-extra2.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-extra1-bold.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/t1-stixgeneral.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathcal-bold.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-mathit.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/stix-extra3.pl
# /usr/local/texlive/2017/texmf-dist/fonts/source/public/stix/ts1-stixgeneral-bolditalic.pl
# /usr/local/texlive/2017/texmf-dist/dvips/pl/config.pl
# /usr/local/texlive/2017/tlpkg/tlpostcode/ptex2pdf-tlpost.pl
# /usr/local/texlive/2017/tlpkg/tlpostcode/dvipdfmx.pl
# /usr/local/texlive/2017/tlpkg/tlpostcode/xetex.pl
# /usr/local/texlive/2017/tlpkg/installer/install-menu-perltk.pl
# /usr/local/texlive/2017/tlpkg/installer/install-menu-wizard.pl
# /usr/local/texlive/2017/tlpkg/installer/install-menu-text.pl
# /usr/local/texlive/2017/tlpkg/installer/ctan-mirrors.pl
# /usr/local/texlive/2017/tlpkg/TeXLive/trans.pl
# /usr/share/vim/vim82/tools/efm_perl.pl
# /usr/share/vim/vim82/tools/efm_filter.pl
# /usr/share/vim/vim82/tools/shtags.pl
# /usr/share/vim/vim82/tools/pltags.pl
# /usr/share/vim/vim82/tutor/tutor.pl
# /usr/share/vim/vim82/doc/vim2html.pl
# /usr/share/CSI/merger.pl
# /usr/share/snmp/snmp_perl_trapd.pl
# Found 369 .pl files in path /usr.

# %% [markdown]
# Suppose we just want the file names, not the full paths.

# %%
def get_list_of_filenames(path,ext='',dump=False):
    process = subprocess.Popen(['find',path,'-type','f'],stdout=subprocess.PIPE,stderr=subprocess.PIPE)
    stdout,stderr = process.communicate()
    if not ext:
        lof = [os.path.basename(f.decode('utf-8')) for f in stdout.split()]
        if dump:
            print('\n'.join(lof))
        return lof
    else:
        lof = [os.path.basename(f.decode('utf-8')) for f in stdout.split() if f.decode('utf-8').endswith('.{}'.format(ext))]
        if dump:
            print('\n'.join(lof))
        return lof

# %%
path = '/usr'
ext = 'pl'
lf = get_list_of_filenames(path,ext)
print('Found {} .{} files in path {}.'.format(len(lf),ext,path))
get_list_of_filenames(path,ext,True)
print('Found {} .{} files in path {}.'.format(len(lf),ext,path))
# Out:
# Found 369 .pl files in path /usr.
# binhex5.18.pl
# stty.pl
# binhex5.28.pl
# scandeps5.30.pl
# scandeps.pl
# debinhex5.30.pl
# stty5.18.pl
# par5.30.pl
# xgettext5.30.pl
# scandeps5.28.pl
# binhex5.30.pl
# scandeps5.18.pl
# xgettext.pl
# binhex.pl
# debinhex5.28.pl
# debinhex5.18.pl
# xgettext5.28.pl
# par5.28.pl
# xgettext5.18.pl
# debinhex.pl
# par.pl
# greylist.pl
# emlog.pl
# tsget.pl
# CA.pl
# CA.pl
# testmod.pl
# highlight.pl
# fixqt4headers.pl
# syncqt.pl
# findclasslist.pl
# aggregate_profile.pl
# profile2mat.pl
# config.pl
# cvs-clean.pl
# conf.change.pl
# config.pl
# cvs-clean.pl
# conf.change.pl
# tsget.pl
# CA.pl
# tsget.pl
# CA.pl
# CA.pl
# genhtmlidx.pl
# genindex.pl
# build.pl
# adjust_checksum.pl
# ziptimetree.pl
# psdmapshortnames.pl
# uni2sfd.pl
# makefdx.pl
# clonevf.pl
# sfd2uni.pl
# hlatex2agl.pl
# fixwada2.pl
# makeuniwada.pl
# tibetan.pl
# feynmf.pl
# cmex10.pl
# cmr10.pl
# cmmi10.pl
# fplmb.pl
# cmbx10.pl
# cmex10.pl
# cmr10.pl
# cmmi10.pl
# cmbx10.pl
# cmbsy10.pl
# cmsy10.pl
# cmmib10.pl
# cmbsy10.pl
# fplmbb.pl
# cmsy10.pl
# cmmib10.pl
# fplmri.pl
# fplmbi.pl
# fplmr.pl
# dvi2pdf.pl
# ltj-unicode-ccfix_make2.pl
# makemaps.pl
# convert.pl
# make-exhyph.pl
# hyphenex.pl
# mkvpkana.pl
# mktfm.pl
# mkutfvf.pl
# mkjp04tfmvf.pl
# mkmlcidvf.pl
# mkcidofm.pl
# mkaltutfvf.pl
# mkcidvf.pl
# mkpropofm.pl
# mkpkana.pl
# base2-h.pl
# base-v.pl
# brsg-v.pl
# brsg-h.pl
# base-h.pl
# base3-v.pl
# base0-h.pl
# base2-v.pl
# birm.pl
# umkvpkana.pl
# umkpkana.pl
# mkutf32list.pl
# mkutfvf_sp.pl
# mktfm_sp.pl
# ubase-h.pl
# ubrsg-h.pl
# ubrsg-v.pl
# ubase-v.pl
# ygoth.pl
# ecbx1000.pl
# yfrak.pl
# cmr10.pl
# ecrm0700.pl
# cmu10.pl
# cmmi10.pl
# cmbx10.pl
# ecrm1000.pl
# cmr7.pl
# cmbsy10.pl
# cmsy10.pl
# cmmib10.pl
# yswab.pl
# upjisr-v.pl
# uprml-h-hk.pl
# uprml-h.pl
# upjisr-h.pl
# upjisr-h-hk.pl
# deweb.pl
# sty2dtx.pl
# makempy.pl
# texfind.pl
# texfont.pl
# mptopdf.pl
# pdftrimwhite.pl
# texdoctk.pl
# htmove.pl
# mk4ht.pl
# htcopy.pl
# pdfatfi.pl
# latexmk.pl
# pst2pdf.pl
# mathspic.pl
# perltex.pl
# cjk-gs-integrate.pl
# makedtx.pl
# multibibliography.pl
# bibdoiadd.pl
# bibmradd.pl
# bbl2bib.pl
# bibzbladd.pl
# ltx2crossrefxml.pl
# mkjobtexmf.pl
# ps2eps.pl
# dosepsbin.pl
# a2ping.pl
# thumbpdf.pl
# pkfix.pl
# texcount.pl
# svn-multi.pl
# fragmaster.pl
# pdfannotextractor.pl
# texdef.pl
# biokey2html2.pl
# biokey2html3.pl
# biokey2html1.pl
# mycv_split_contents.pl
# ttf2kotexfont.pl
# komkindex.pl
# jamo-normalize.pl
# latexindent.pl
# texindy.pl
# xindy.pl
# splitindex.pl
# includeres.pl
# extractres.pl
# psjoin.pl
# srcredact.pl
# kanji-fontmap-creator.pl
# kanji-config-updmap.pl
# ulqda.pl
# rubikrotation.pl
# latexrevise.pl
# latexdiff-vc.pl
# latexdiff.pl
# mf2pt1.pl
# pdflatexpicscale.pl
# vpe.pl
# ltximg.pl
# epstopdf.pl
# pedigree.pl
# ctanupload.pl
# tlmgrgui.pl
# tlmgr.pl
# uninstall-win32.pl
# e2pall.pl
# mktexlsr.pl
# updmap.pl
# fmtutil.pl
# texfot.pl
# pdfcrop.pl
# check_enc.pl
# README.pl
# mp2html.pl
# syntaxform.pl
# README.pl
# generateswitch.pl
# generateswitch.pl
# wrfiles.pl
# fixdate.pl
# nmbibtex.pl
# gb7714texttobib.pl
# sample.pl
# ibyhyph.pl
# fullref.pl
# checksum.pl
# gen-map.pl
# bin-cjkutils.pl
# cjk.pl
# garuda-c90.pl
# cjk-build.pl
# norasi-c90.pl
# dnp.pl
# c90.pl
# inv1html.pl
# test-SGMLS.pl
# sgmlspl.pl
# skel.pl
# inv2html.pl
# inv2lat.pl
# myinit.pl
# reg_list.pl
# fixdate.pl
# codean.pl
# cyrename.pl
# mkmlsmf.pl
# makeunidef.pl
# latexout.pl
# discovermacro.pl
# beamer-themes.pl
# polices.pl
# gen_pdf.pl
# porzadki.pl
# version.pl
# clean-case.pl
# version.pl
# clean-case.pl
# make-enc.pl
# pst-geo-compress.pl
# pst-geo-decompress.pl
# filtre.pl
# rgrsc10.pl
# dad-to-utf8.pl
# utf8-to-dad.pl
# make-dad-font.pl
# upzhm-v.pl
# upzhm-h.pl
# mes-list-expand.pl
# CheckConformance.pl
# KerningNumerals.pl
# texlive.pl
# split.pl
# mod.pl
# l.pl
# status.pl
# goth7.pl
# min6.pl
# tmin8.pl
# min7.pl
# tgoth10.pl
# tmin9.pl
# tgoth5.pl
# goth6.pl
# min8.pl
# tmin6.pl
# goth9.pl
# goth8.pl
# tmin10.pl
# min9.pl
# tmin7.pl
# goth10.pl
# tgoth8.pl
# min10.pl
# tmin5.pl
# tgoth9.pl
# goth5.pl
# tgoth6.pl
# tgoth7.pl
# min5.pl
# ngoth9.pl
# nmin9.pl
# nmin8.pl
# ngoth8.pl
# nmin7.pl
# ngoth7.pl
# ngoth6.pl
# nmin6.pl
# ngoth5.pl
# nmin5.pl
# ngoth10.pl
# nmin10.pl
# jisn-v.pl
# jis-v.pl
# jis.pl
# jisn.pl
# ot2-stixgeneral-italic.pl
# ot1-stixgeneral-bolditalic.pl
# stix-mathcal.pl
# stix-mathrm.pl
# ot1-stixgeneral-bold.pl
# ot1-stixgeneral.pl
# ts1-stixgeneral-italic.pl
# ts1-stixgeneral.pl
# stix-mathrm-bold.pl
# stix-mathtt.pl
# stix-mathit-bold.pl
# ot2-stixgeneral-bold.pl
# stix-extra1.pl
# stix-mathsf-bold.pl
# stix-mathbbit-bold.pl
# stix-mathsf.pl
# stix-mathscr.pl
# ot2-stixgeneral.pl
# stix-mathbb.pl
# t1-stixgeneral-italic.pl
# stix-mathfrak.pl
# stix-mathbb-bold.pl
# t1-stixgeneral-bolditalic.pl
# t1-stixgeneral-bold.pl
# stix-extra2-bold.pl
# stix-mathsfit.pl
# stix-mathex.pl
# stix-mathex-bold.pl
# stix-mathsfit-bold.pl
# ot2-stixgeneral-bolditalic.pl
# stix-mathtt-bold.pl
# ot1-stixgeneral-italic.pl
# ts1-stixgeneral-bold.pl
# stix-extra3-bold.pl
# stix-mathscr-bold.pl
# stix-mathfrak-bold.pl
# stix-mathbbit.pl
# stix-extra2.pl
# stix-extra1-bold.pl
# t1-stixgeneral.pl
# stix-mathcal-bold.pl
# stix-mathit.pl
# stix-extra3.pl
# ts1-stixgeneral-bolditalic.pl
# config.pl
# ptex2pdf-tlpost.pl
# dvipdfmx.pl
# xetex.pl
# install-menu-perltk.pl
# install-menu-wizard.pl
# install-menu-text.pl
# ctan-mirrors.pl
# trans.pl
# efm_perl.pl
# efm_filter.pl
# shtags.pl
# pltags.pl
# tutor.pl
# vim2html.pl
# merger.pl
# snmp_perl_trapd.pl
# Found 369 .pl files in path /usr.

# %% [markdown]
# Let's do the same thing using the os.walk() to recursively traverse through the directory tree

# %%
from collections import namedtuple

fret = namedtuple('fret', 'fnames lof')

def get_list_of_filenames_sub(path,ext=''):
    fnames = []
    for root, d_names, f_names in os.walk(path):
        if not ext:
            fnames.extend(f_names)
        else:
            fnames.extend(filter(lambda x:x.endswith('.{}'.format(ext)), f_names))
    lof = [os.path.join(root,f) for f in fnames]
    return fret(fnames,lof)

# %%
path = '/usr'
ext = 'pl'
a = get_list_of_filenames_sub(path,ext)
print('Found ',len(a.fnames),' perl files in {}'.format(path))
print('\n'.join(a.fnames))
print('\n'.join(a.lof))
# Out:
# Found  371  perl files in /usr
# binhex5.18.pl
# stty.pl
# binhex5.28.pl
# scandeps5.30.pl
# scandeps.pl
# debinhex5.30.pl
# stty5.18.pl
# par5.30.pl
# xgettext5.30.pl
# scandeps5.28.pl
# binhex5.30.pl
# scandeps5.18.pl
# xgettext.pl
# binhex.pl
# debinhex5.28.pl
# debinhex5.18.pl
# xgettext5.28.pl
# par5.28.pl
# xgettext5.18.pl
# debinhex.pl
# par.pl
# emlog.pl
# greylist.pl
# aggregate_profile.pl
# profile2mat.pl
# tsget.pl
# CA.pl
# CA.pl
# testmod.pl
# highlight.pl
# fixqt4headers.pl
# syncqt.pl
# findclasslist.pl
# aggregate_profile.pl
# profile2mat.pl
# config.pl
# cvs-clean.pl
# conf.change.pl
# config.pl
# cvs-clean.pl
# conf.change.pl
# tsget.pl
# CA.pl
# tsget.pl
# CA.pl
# CA.pl
# genhtmlidx.pl
# genindex.pl
# build.pl
# adjust_checksum.pl
# ziptimetree.pl
# psdmapshortnames.pl
# uni2sfd.pl
# makefdx.pl
# clonevf.pl
# sfd2uni.pl
# hlatex2agl.pl
# fixwada2.pl
# makeuniwada.pl
# tibetan.pl
# feynmf.pl
# cmex10.pl
# cmr10.pl
# cmmi10.pl
# fplmb.pl
# cmbx10.pl
# cmbsy10.pl
# fplmbb.pl
# cmsy10.pl
# cmmib10.pl
# fplmri.pl
# fplmbi.pl
# fplmr.pl
# cmex10.pl
# cmr10.pl
# cmmi10.pl
# cmbx10.pl
# cmbsy10.pl
# cmsy10.pl
# cmmib10.pl
# dvi2pdf.pl
# ltj-unicode-ccfix_make2.pl
# makemaps.pl
# convert.pl
# make-exhyph.pl
# hyphenex.pl
# mkvpkana.pl
# mktfm.pl
# mkutfvf.pl
# mkjp04tfmvf.pl
# mkmlcidvf.pl
# mkcidofm.pl
# mkaltutfvf.pl
# mkcidvf.pl
# mkpropofm.pl
# mkpkana.pl
# base2-h.pl
# base-v.pl
# brsg-v.pl
# brsg-h.pl
# base-h.pl
# base3-v.pl
# base0-h.pl
# base2-v.pl
# birm.pl
# umkvpkana.pl
# umkpkana.pl
# mkutf32list.pl
# mkutfvf_sp.pl
# mktfm_sp.pl
# ubase-h.pl
# ubrsg-h.pl
# ubrsg-v.pl
# ubase-v.pl
# ygoth.pl
# ecbx1000.pl
# yfrak.pl
# cmr10.pl
# ecrm0700.pl
# cmu10.pl
# cmmi10.pl
# cmbx10.pl
# ecrm1000.pl
# cmr7.pl
# cmbsy10.pl
# cmsy10.pl
# cmmib10.pl
# yswab.pl
# upjisr-v.pl
# uprml-h-hk.pl
# uprml-h.pl
# upjisr-h.pl
# upjisr-h-hk.pl
# deweb.pl
# sty2dtx.pl
# makempy.pl
# texfind.pl
# texfont.pl
# mptopdf.pl
# pdftrimwhite.pl
# texdoctk.pl
# htmove.pl
# mk4ht.pl
# htcopy.pl
# pdfatfi.pl
# latexmk.pl
# pst2pdf.pl
# mathspic.pl
# perltex.pl
# cjk-gs-integrate.pl
# makedtx.pl
# multibibliography.pl
# bibdoiadd.pl
# bibmradd.pl
# bbl2bib.pl
# bibzbladd.pl
# ltx2crossrefxml.pl
# mkjobtexmf.pl
# ps2eps.pl
# dosepsbin.pl
# a2ping.pl
# thumbpdf.pl
# pkfix.pl
# texcount.pl
# svn-multi.pl
# fragmaster.pl
# pdfannotextractor.pl
# texdef.pl
# biokey2html2.pl
# biokey2html3.pl
# biokey2html1.pl
# mycv_split_contents.pl
# ttf2kotexfont.pl
# komkindex.pl
# jamo-normalize.pl
# latexindent.pl
# texindy.pl
# xindy.pl
# splitindex.pl
# includeres.pl
# extractres.pl
# psjoin.pl
# srcredact.pl
# kanji-fontmap-creator.pl
# kanji-config-updmap.pl
# ulqda.pl
# rubikrotation.pl
# latexrevise.pl
# latexdiff-vc.pl
# latexdiff.pl
# mf2pt1.pl
# pdflatexpicscale.pl
# vpe.pl
# ltximg.pl
# epstopdf.pl
# pedigree.pl
# ctanupload.pl
# tlmgrgui.pl
# tlmgr.pl
# uninstall-win32.pl
# e2pall.pl
# mktexlsr.pl
# updmap.pl
# fmtutil.pl
# texfot.pl
# pdfcrop.pl
# check_enc.pl
# README.pl
# mp2html.pl
# syntaxform.pl
# README.pl
# generateswitch.pl
# generateswitch.pl
# wrfiles.pl
# fixdate.pl
# nmbibtex.pl
# gb7714texttobib.pl
# sample.pl
# ibyhyph.pl
# fullref.pl
# checksum.pl
# gen-map.pl
# bin-cjkutils.pl
# cjk.pl
# garuda-c90.pl
# cjk-build.pl
# norasi-c90.pl
# dnp.pl
# c90.pl
# inv1html.pl
# test-SGMLS.pl
# sgmlspl.pl
# skel.pl
# inv2html.pl
# inv2lat.pl
# myinit.pl
# reg_list.pl
# fixdate.pl
# codean.pl
# cyrename.pl
# mkmlsmf.pl
# makeunidef.pl
# latexout.pl
# discovermacro.pl
# beamer-themes.pl
# polices.pl
# gen_pdf.pl
# porzadki.pl
# version.pl
# clean-case.pl
# version.pl
# clean-case.pl
# make-enc.pl
# pst-geo-compress.pl
# pst-geo-decompress.pl
# filtre.pl
# rgrsc10.pl
# dad-to-utf8.pl
# utf8-to-dad.pl
# make-dad-font.pl
# upzhm-v.pl
# upzhm-h.pl
# mes-list-expand.pl
# CheckConformance.pl
# KerningNumerals.pl
# texlive.pl
# split.pl
# mod.pl
# l.pl
# status.pl
# goth7.pl
# min6.pl
# tmin8.pl
# min7.pl
# tgoth10.pl
# tmin9.pl
# tgoth5.pl
# goth6.pl
# min8.pl
# tmin6.pl
# goth9.pl
# goth8.pl
# tmin10.pl
# min9.pl
# tmin7.pl
# goth10.pl
# tgoth8.pl
# min10.pl
# tmin5.pl
# tgoth9.pl
# goth5.pl
# tgoth6.pl
# tgoth7.pl
# min5.pl
# ngoth9.pl
# nmin9.pl
# nmin8.pl
# ngoth8.pl
# nmin7.pl
# ngoth7.pl
# ngoth6.pl
# nmin6.pl
# ngoth5.pl
# nmin5.pl
# ngoth10.pl
# nmin10.pl
# jisn-v.pl
# jis-v.pl
# jis.pl
# jisn.pl
# ot2-stixgeneral-italic.pl
# ot1-stixgeneral-bolditalic.pl
# stix-mathcal.pl
# stix-mathrm.pl
# ot1-stixgeneral-bold.pl
# ot1-stixgeneral.pl
# ts1-stixgeneral-italic.pl
# ts1-stixgeneral.pl
# stix-mathrm-bold.pl
# stix-mathtt.pl
# stix-mathit-bold.pl
# ot2-stixgeneral-bold.pl
# stix-extra1.pl
# stix-mathsf-bold.pl
# stix-mathbbit-bold.pl
# stix-mathsf.pl
# stix-mathscr.pl
# ot2-stixgeneral.pl
# stix-mathbb.pl
# t1-stixgeneral-italic.pl
# stix-mathfrak.pl
# stix-mathbb-bold.pl
# t1-stixgeneral-bolditalic.pl
# t1-stixgeneral-bold.pl
# stix-extra2-bold.pl
# stix-mathsfit.pl
# stix-mathex.pl
# stix-mathex-bold.pl
# stix-mathsfit-bold.pl
# ot2-stixgeneral-bolditalic.pl
# stix-mathtt-bold.pl
# ot1-stixgeneral-italic.pl
# ts1-stixgeneral-bold.pl
# stix-extra3-bold.pl
# stix-mathscr-bold.pl
# stix-mathfrak-bold.pl
# stix-mathbbit.pl
# stix-extra2.pl
# stix-extra1-bold.pl
# t1-stixgeneral.pl
# stix-mathcal-bold.pl
# stix-mathit.pl
# stix-extra3.pl
# ts1-stixgeneral-bolditalic.pl
# config.pl
# ptex2pdf-tlpost.pl
# dvipdfmx.pl
# xetex.pl
# install-menu-perltk.pl
# install-menu-wizard.pl
# install-menu-text.pl
# ctan-mirrors.pl
# trans.pl
# efm_perl.pl
# efm_filter.pl
# shtags.pl
# pltags.pl
# tutor.pl
# vim2html.pl
# merger.pl
# snmp_perl_trapd.pl
# /usr/share/thermald.bundle/Contents/Resources/binhex5.18.pl
# /usr/share/thermald.bundle/Contents/Resources/stty.pl
# /usr/share/thermald.bundle/Contents/Resources/binhex5.28.pl
# /usr/share/thermald.bundle/Contents/Resources/scandeps5.30.pl
# /usr/share/thermald.bundle/Contents/Resources/scandeps.pl
# /usr/share/thermald.bundle/Contents/Resources/debinhex5.30.pl
# /usr/share/thermald.bundle/Contents/Resources/stty5.18.pl
# /usr/share/thermald.bundle/Contents/Resources/par5.30.pl
# /usr/share/thermald.bundle/Contents/Resources/xgettext5.30.pl
# /usr/share/thermald.bundle/Contents/Resources/scandeps5.28.pl
# /usr/share/thermald.bundle/Contents/Resources/binhex5.30.pl
# /usr/share/thermald.bundle/Contents/Resources/scandeps5.18.pl
# /usr/share/thermald.bundle/Contents/Resources/xgettext.pl
# /usr/share/thermald.bundle/Contents/Resources/binhex.pl
# /usr/share/thermald.bundle/Contents/Resources/debinhex5.28.pl
# /usr/share/thermald.bundle/Contents/Resources/debinhex5.18.pl
# /usr/share/thermald.bundle/Contents/Resources/xgettext5.28.pl
# /usr/share/thermald.bundle/Contents/Resources/par5.28.pl
# /usr/share/thermald.bundle/Contents/Resources/xgettext5.18.pl
# /usr/share/thermald.bundle/Contents/Resources/debinhex.pl
# /usr/share/thermald.bundle/Contents/Resources/par.pl
# /usr/share/thermald.bundle/Contents/Resources/emlog.pl
# /usr/share/thermald.bundle/Contents/Resources/greylist.pl
# /usr/share/thermald.bundle/Contents/Resources/aggregate_profile.pl
# /usr/share/thermald.bundle/Contents/Resources/profile2mat.pl
# /usr/share/thermald.bundle/Contents/Resources/tsget.pl
# /usr/share/thermald.bundle/Contents/Resources/CA.pl
# /usr/share/thermald.bundle/Contents/Resources/CA.pl
# /usr/share/thermald.bundle/Contents/Resources/testmod.pl
# /usr/share/thermald.bundle/Contents/Resources/highlight.pl
# /usr/share/thermald.bundle/Contents/Resources/fixqt4headers.pl
# /usr/share/thermald.bundle/Contents/Resources/syncqt.pl
# /usr/share/thermald.bundle/Contents/Resources/findclasslist.pl
# /usr/share/thermald.bundle/Contents/Resources/aggregate_profile.pl
# /usr/share/thermald.bundle/Contents/Resources/profile2mat.pl
# /usr/share/thermald.bundle/Contents/Resources/config.pl
# /usr/share/thermald.bundle/Contents/Resources/cvs-clean.pl
# /usr/share/thermald.bundle/Contents/Resources/conf.change.pl
# /usr/share/thermald.bundle/Contents/Resources/config.pl
# /usr/share/thermald.bundle/Contents/Resources/cvs-clean.pl
# /usr/share/thermald.bundle/Contents/Resources/conf.change.pl
# /usr/share/thermald.bundle/Contents/Resources/tsget.pl
# /usr/share/thermald.bundle/Contents/Resources/CA.pl
# /usr/share/thermald.bundle/Contents/Resources/tsget.pl
# /usr/share/thermald.bundle/Contents/Resources/CA.pl
# /usr/share/thermald.bundle/Contents/Resources/CA.pl
# /usr/share/thermald.bundle/Contents/Resources/genhtmlidx.pl
# /usr/share/thermald.bundle/Contents/Resources/genindex.pl
# /usr/share/thermald.bundle/Contents/Resources/build.pl
# /usr/share/thermald.bundle/Contents/Resources/adjust_checksum.pl
# /usr/share/thermald.bundle/Contents/Resources/ziptimetree.pl
# /usr/share/thermald.bundle/Contents/Resources/psdmapshortnames.pl
# /usr/share/thermald.bundle/Contents/Resources/uni2sfd.pl
# /usr/share/thermald.bundle/Contents/Resources/makefdx.pl
# /usr/share/thermald.bundle/Contents/Resources/clonevf.pl
# /usr/share/thermald.bundle/Contents/Resources/sfd2uni.pl
# /usr/share/thermald.bundle/Contents/Resources/hlatex2agl.pl
# /usr/share/thermald.bundle/Contents/Resources/fixwada2.pl
# /usr/share/thermald.bundle/Contents/Resources/makeuniwada.pl
# /usr/share/thermald.bundle/Contents/Resources/tibetan.pl
# /usr/share/thermald.bundle/Contents/Resources/feynmf.pl
# /usr/share/thermald.bundle/Contents/Resources/cmex10.pl
# /usr/share/thermald.bundle/Contents/Resources/cmr10.pl
# /usr/share/thermald.bundle/Contents/Resources/cmmi10.pl
# /usr/share/thermald.bundle/Contents/Resources/fplmb.pl
# /usr/share/thermald.bundle/Contents/Resources/cmbx10.pl
# /usr/share/thermald.bundle/Contents/Resources/cmbsy10.pl
# /usr/share/thermald.bundle/Contents/Resources/fplmbb.pl
# /usr/share/thermald.bundle/Contents/Resources/cmsy10.pl
# /usr/share/thermald.bundle/Contents/Resources/cmmib10.pl
# /usr/share/thermald.bundle/Contents/Resources/fplmri.pl
# /usr/share/thermald.bundle/Contents/Resources/fplmbi.pl
# /usr/share/thermald.bundle/Contents/Resources/fplmr.pl
# /usr/share/thermald.bundle/Contents/Resources/cmex10.pl
# /usr/share/thermald.bundle/Contents/Resources/cmr10.pl
# /usr/share/thermald.bundle/Contents/Resources/cmmi10.pl
# /usr/share/thermald.bundle/Contents/Resources/cmbx10.pl
# /usr/share/thermald.bundle/Contents/Resources/cmbsy10.pl
# /usr/share/thermald.bundle/Contents/Resources/cmsy10.pl
# /usr/share/thermald.bundle/Contents/Resources/cmmib10.pl
# /usr/share/thermald.bundle/Contents/Resources/dvi2pdf.pl
# /usr/share/thermald.bundle/Contents/Resources/ltj-unicode-ccfix_make2.pl
# /usr/share/thermald.bundle/Contents/Resources/makemaps.pl
# /usr/share/thermald.bundle/Contents/Resources/convert.pl
# /usr/share/thermald.bundle/Contents/Resources/make-exhyph.pl
# /usr/share/thermald.bundle/Contents/Resources/hyphenex.pl
# /usr/share/thermald.bundle/Contents/Resources/mkvpkana.pl
# /usr/share/thermald.bundle/Contents/Resources/mktfm.pl
# /usr/share/thermald.bundle/Contents/Resources/mkutfvf.pl
# /usr/share/thermald.bundle/Contents/Resources/mkjp04tfmvf.pl
# /usr/share/thermald.bundle/Contents/Resources/mkmlcidvf.pl
# /usr/share/thermald.bundle/Contents/Resources/mkcidofm.pl
# /usr/share/thermald.bundle/Contents/Resources/mkaltutfvf.pl
# /usr/share/thermald.bundle/Contents/Resources/mkcidvf.pl
# /usr/share/thermald.bundle/Contents/Resources/mkpropofm.pl
# /usr/share/thermald.bundle/Contents/Resources/mkpkana.pl
# /usr/share/thermald.bundle/Contents/Resources/base2-h.pl
# /usr/share/thermald.bundle/Contents/Resources/base-v.pl
# /usr/share/thermald.bundle/Contents/Resources/brsg-v.pl
# /usr/share/thermald.bundle/Contents/Resources/brsg-h.pl
# /usr/share/thermald.bundle/Contents/Resources/base-h.pl
# /usr/share/thermald.bundle/Contents/Resources/base3-v.pl
# /usr/share/thermald.bundle/Contents/Resources/base0-h.pl
# /usr/share/thermald.bundle/Contents/Resources/base2-v.pl
# /usr/share/thermald.bundle/Contents/Resources/birm.pl
# /usr/share/thermald.bundle/Contents/Resources/umkvpkana.pl
# /usr/share/thermald.bundle/Contents/Resources/umkpkana.pl
# /usr/share/thermald.bundle/Contents/Resources/mkutf32list.pl
# /usr/share/thermald.bundle/Contents/Resources/mkutfvf_sp.pl
# /usr/share/thermald.bundle/Contents/Resources/mktfm_sp.pl
# /usr/share/thermald.bundle/Contents/Resources/ubase-h.pl
# /usr/share/thermald.bundle/Contents/Resources/ubrsg-h.pl
# /usr/share/thermald.bundle/Contents/Resources/ubrsg-v.pl
# /usr/share/thermald.bundle/Contents/Resources/ubase-v.pl
# /usr/share/thermald.bundle/Contents/Resources/ygoth.pl
# /usr/share/thermald.bundle/Contents/Resources/ecbx1000.pl
# /usr/share/thermald.bundle/Contents/Resources/yfrak.pl
# /usr/share/thermald.bundle/Contents/Resources/cmr10.pl
# /usr/share/thermald.bundle/Contents/Resources/ecrm0700.pl
# /usr/share/thermald.bundle/Contents/Resources/cmu10.pl
# /usr/share/thermald.bundle/Contents/Resources/cmmi10.pl
# /usr/share/thermald.bundle/Contents/Resources/cmbx10.pl
# /usr/share/thermald.bundle/Contents/Resources/ecrm1000.pl
# /usr/share/thermald.bundle/Contents/Resources/cmr7.pl
# /usr/share/thermald.bundle/Contents/Resources/cmbsy10.pl
# /usr/share/thermald.bundle/Contents/Resources/cmsy10.pl
# /usr/share/thermald.bundle/Contents/Resources/cmmib10.pl
# /usr/share/thermald.bundle/Contents/Resources/yswab.pl
# /usr/share/thermald.bundle/Contents/Resources/upjisr-v.pl
# /usr/share/thermald.bundle/Contents/Resources/uprml-h-hk.pl
# /usr/share/thermald.bundle/Contents/Resources/uprml-h.pl
# /usr/share/thermald.bundle/Contents/Resources/upjisr-h.pl
# /usr/share/thermald.bundle/Contents/Resources/upjisr-h-hk.pl
# /usr/share/thermald.bundle/Contents/Resources/deweb.pl
# /usr/share/thermald.bundle/Contents/Resources/sty2dtx.pl
# /usr/share/thermald.bundle/Contents/Resources/makempy.pl
# /usr/share/thermald.bundle/Contents/Resources/texfind.pl
# /usr/share/thermald.bundle/Contents/Resources/texfont.pl
# /usr/share/thermald.bundle/Contents/Resources/mptopdf.pl
# /usr/share/thermald.bundle/Contents/Resources/pdftrimwhite.pl
# /usr/share/thermald.bundle/Contents/Resources/texdoctk.pl
# /usr/share/thermald.bundle/Contents/Resources/htmove.pl
# /usr/share/thermald.bundle/Contents/Resources/mk4ht.pl
# /usr/share/thermald.bundle/Contents/Resources/htcopy.pl
# /usr/share/thermald.bundle/Contents/Resources/pdfatfi.pl
# /usr/share/thermald.bundle/Contents/Resources/latexmk.pl
# /usr/share/thermald.bundle/Contents/Resources/pst2pdf.pl
# /usr/share/thermald.bundle/Contents/Resources/mathspic.pl
# /usr/share/thermald.bundle/Contents/Resources/perltex.pl
# /usr/share/thermald.bundle/Contents/Resources/cjk-gs-integrate.pl
# /usr/share/thermald.bundle/Contents/Resources/makedtx.pl
# /usr/share/thermald.bundle/Contents/Resources/multibibliography.pl
# /usr/share/thermald.bundle/Contents/Resources/bibdoiadd.pl
# /usr/share/thermald.bundle/Contents/Resources/bibmradd.pl
# /usr/share/thermald.bundle/Contents/Resources/bbl2bib.pl
# /usr/share/thermald.bundle/Contents/Resources/bibzbladd.pl
# /usr/share/thermald.bundle/Contents/Resources/ltx2crossrefxml.pl
# /usr/share/thermald.bundle/Contents/Resources/mkjobtexmf.pl
# /usr/share/thermald.bundle/Contents/Resources/ps2eps.pl
# /usr/share/thermald.bundle/Contents/Resources/dosepsbin.pl
# /usr/share/thermald.bundle/Contents/Resources/a2ping.pl
# /usr/share/thermald.bundle/Contents/Resources/thumbpdf.pl
# /usr/share/thermald.bundle/Contents/Resources/pkfix.pl
# /usr/share/thermald.bundle/Contents/Resources/texcount.pl
# /usr/share/thermald.bundle/Contents/Resources/svn-multi.pl
# /usr/share/thermald.bundle/Contents/Resources/fragmaster.pl
# /usr/share/thermald.bundle/Contents/Resources/pdfannotextractor.pl
# /usr/share/thermald.bundle/Contents/Resources/texdef.pl
# /usr/share/thermald.bundle/Contents/Resources/biokey2html2.pl
# /usr/share/thermald.bundle/Contents/Resources/biokey2html3.pl
# /usr/share/thermald.bundle/Contents/Resources/biokey2html1.pl
# /usr/share/thermald.bundle/Contents/Resources/mycv_split_contents.pl
# /usr/share/thermald.bundle/Contents/Resources/ttf2kotexfont.pl
# /usr/share/thermald.bundle/Contents/Resources/komkindex.pl
# /usr/share/thermald.bundle/Contents/Resources/jamo-normalize.pl
# /usr/share/thermald.bundle/Contents/Resources/latexindent.pl
# /usr/share/thermald.bundle/Contents/Resources/texindy.pl
# /usr/share/thermald.bundle/Contents/Resources/xindy.pl
# /usr/share/thermald.bundle/Contents/Resources/splitindex.pl
# /usr/share/thermald.bundle/Contents/Resources/includeres.pl
# /usr/share/thermald.bundle/Contents/Resources/extractres.pl
# /usr/share/thermald.bundle/Contents/Resources/psjoin.pl
# /usr/share/thermald.bundle/Contents/Resources/srcredact.pl
# /usr/share/thermald.bundle/Contents/Resources/kanji-fontmap-creator.pl
# /usr/share/thermald.bundle/Contents/Resources/kanji-config-updmap.pl
# /usr/share/thermald.bundle/Contents/Resources/ulqda.pl
# /usr/share/thermald.bundle/Contents/Resources/rubikrotation.pl
# /usr/share/thermald.bundle/Contents/Resources/latexrevise.pl
# /usr/share/thermald.bundle/Contents/Resources/latexdiff-vc.pl
# /usr/share/thermald.bundle/Contents/Resources/latexdiff.pl
# /usr/share/thermald.bundle/Contents/Resources/mf2pt1.pl
# /usr/share/thermald.bundle/Contents/Resources/pdflatexpicscale.pl
# /usr/share/thermald.bundle/Contents/Resources/vpe.pl
# /usr/share/thermald.bundle/Contents/Resources/ltximg.pl
# /usr/share/thermald.bundle/Contents/Resources/epstopdf.pl
# /usr/share/thermald.bundle/Contents/Resources/pedigree.pl
# /usr/share/thermald.bundle/Contents/Resources/ctanupload.pl
# /usr/share/thermald.bundle/Contents/Resources/tlmgrgui.pl
# /usr/share/thermald.bundle/Contents/Resources/tlmgr.pl
# /usr/share/thermald.bundle/Contents/Resources/uninstall-win32.pl
# /usr/share/thermald.bundle/Contents/Resources/e2pall.pl
# /usr/share/thermald.bundle/Contents/Resources/mktexlsr.pl
# /usr/share/thermald.bundle/Contents/Resources/updmap.pl
# /usr/share/thermald.bundle/Contents/Resources/fmtutil.pl
# /usr/share/thermald.bundle/Contents/Resources/texfot.pl
# /usr/share/thermald.bundle/Contents/Resources/pdfcrop.pl
# /usr/share/thermald.bundle/Contents/Resources/check_enc.pl
# /usr/share/thermald.bundle/Contents/Resources/README.pl
# /usr/share/thermald.bundle/Contents/Resources/mp2html.pl
# /usr/share/thermald.bundle/Contents/Resources/syntaxform.pl
# /usr/share/thermald.bundle/Contents/Resources/README.pl
# /usr/share/thermald.bundle/Contents/Resources/generateswitch.pl
# /usr/share/thermald.bundle/Contents/Resources/generateswitch.pl
# /usr/share/thermald.bundle/Contents/Resources/wrfiles.pl
# /usr/share/thermald.bundle/Contents/Resources/fixdate.pl
# /usr/share/thermald.bundle/Contents/Resources/nmbibtex.pl
# /usr/share/thermald.bundle/Contents/Resources/gb7714texttobib.pl
# /usr/share/thermald.bundle/Contents/Resources/sample.pl
# /usr/share/thermald.bundle/Contents/Resources/ibyhyph.pl
# /usr/share/thermald.bundle/Contents/Resources/fullref.pl
# /usr/share/thermald.bundle/Contents/Resources/checksum.pl
# /usr/share/thermald.bundle/Contents/Resources/gen-map.pl
# /usr/share/thermald.bundle/Contents/Resources/bin-cjkutils.pl
# /usr/share/thermald.bundle/Contents/Resources/cjk.pl
# /usr/share/thermald.bundle/Contents/Resources/garuda-c90.pl
# /usr/share/thermald.bundle/Contents/Resources/cjk-build.pl
# /usr/share/thermald.bundle/Contents/Resources/norasi-c90.pl
# /usr/share/thermald.bundle/Contents/Resources/dnp.pl
# /usr/share/thermald.bundle/Contents/Resources/c90.pl
# /usr/share/thermald.bundle/Contents/Resources/inv1html.pl
# /usr/share/thermald.bundle/Contents/Resources/test-SGMLS.pl
# /usr/share/thermald.bundle/Contents/Resources/sgmlspl.pl
# /usr/share/thermald.bundle/Contents/Resources/skel.pl
# /usr/share/thermald.bundle/Contents/Resources/inv2html.pl
# /usr/share/thermald.bundle/Contents/Resources/inv2lat.pl
# /usr/share/thermald.bundle/Contents/Resources/myinit.pl
# /usr/share/thermald.bundle/Contents/Resources/reg_list.pl
# /usr/share/thermald.bundle/Contents/Resources/fixdate.pl
# /usr/share/thermald.bundle/Contents/Resources/codean.pl
# /usr/share/thermald.bundle/Contents/Resources/cyrename.pl
# /usr/share/thermald.bundle/Contents/Resources/mkmlsmf.pl
# /usr/share/thermald.bundle/Contents/Resources/makeunidef.pl
# /usr/share/thermald.bundle/Contents/Resources/latexout.pl
# /usr/share/thermald.bundle/Contents/Resources/discovermacro.pl
# /usr/share/thermald.bundle/Contents/Resources/beamer-themes.pl
# /usr/share/thermald.bundle/Contents/Resources/polices.pl
# /usr/share/thermald.bundle/Contents/Resources/gen_pdf.pl
# /usr/share/thermald.bundle/Contents/Resources/porzadki.pl
# /usr/share/thermald.bundle/Contents/Resources/version.pl
# /usr/share/thermald.bundle/Contents/Resources/clean-case.pl
# /usr/share/thermald.bundle/Contents/Resources/version.pl
# /usr/share/thermald.bundle/Contents/Resources/clean-case.pl
# /usr/share/thermald.bundle/Contents/Resources/make-enc.pl
# /usr/share/thermald.bundle/Contents/Resources/pst-geo-compress.pl
# /usr/share/thermald.bundle/Contents/Resources/pst-geo-decompress.pl
# /usr/share/thermald.bundle/Contents/Resources/filtre.pl
# /usr/share/thermald.bundle/Contents/Resources/rgrsc10.pl
# /usr/share/thermald.bundle/Contents/Resources/dad-to-utf8.pl
# /usr/share/thermald.bundle/Contents/Resources/utf8-to-dad.pl
# /usr/share/thermald.bundle/Contents/Resources/make-dad-font.pl
# /usr/share/thermald.bundle/Contents/Resources/upzhm-v.pl
# /usr/share/thermald.bundle/Contents/Resources/upzhm-h.pl
# /usr/share/thermald.bundle/Contents/Resources/mes-list-expand.pl
# /usr/share/thermald.bundle/Contents/Resources/CheckConformance.pl
# /usr/share/thermald.bundle/Contents/Resources/KerningNumerals.pl
# /usr/share/thermald.bundle/Contents/Resources/texlive.pl
# /usr/share/thermald.bundle/Contents/Resources/split.pl
# /usr/share/thermald.bundle/Contents/Resources/mod.pl
# /usr/share/thermald.bundle/Contents/Resources/l.pl
# /usr/share/thermald.bundle/Contents/Resources/status.pl
# /usr/share/thermald.bundle/Contents/Resources/goth7.pl
# /usr/share/thermald.bundle/Contents/Resources/min6.pl
# /usr/share/thermald.bundle/Contents/Resources/tmin8.pl
# /usr/share/thermald.bundle/Contents/Resources/min7.pl
# /usr/share/thermald.bundle/Contents/Resources/tgoth10.pl
# /usr/share/thermald.bundle/Contents/Resources/tmin9.pl
# /usr/share/thermald.bundle/Contents/Resources/tgoth5.pl
# /usr/share/thermald.bundle/Contents/Resources/goth6.pl
# /usr/share/thermald.bundle/Contents/Resources/min8.pl
# /usr/share/thermald.bundle/Contents/Resources/tmin6.pl
# /usr/share/thermald.bundle/Contents/Resources/goth9.pl
# /usr/share/thermald.bundle/Contents/Resources/goth8.pl
# /usr/share/thermald.bundle/Contents/Resources/tmin10.pl
# /usr/share/thermald.bundle/Contents/Resources/min9.pl
# /usr/share/thermald.bundle/Contents/Resources/tmin7.pl
# /usr/share/thermald.bundle/Contents/Resources/goth10.pl
# /usr/share/thermald.bundle/Contents/Resources/tgoth8.pl
# /usr/share/thermald.bundle/Contents/Resources/min10.pl
# /usr/share/thermald.bundle/Contents/Resources/tmin5.pl
# /usr/share/thermald.bundle/Contents/Resources/tgoth9.pl
# /usr/share/thermald.bundle/Contents/Resources/goth5.pl
# /usr/share/thermald.bundle/Contents/Resources/tgoth6.pl
# /usr/share/thermald.bundle/Contents/Resources/tgoth7.pl
# /usr/share/thermald.bundle/Contents/Resources/min5.pl
# /usr/share/thermald.bundle/Contents/Resources/ngoth9.pl
# /usr/share/thermald.bundle/Contents/Resources/nmin9.pl
# /usr/share/thermald.bundle/Contents/Resources/nmin8.pl
# /usr/share/thermald.bundle/Contents/Resources/ngoth8.pl
# /usr/share/thermald.bundle/Contents/Resources/nmin7.pl
# /usr/share/thermald.bundle/Contents/Resources/ngoth7.pl
# /usr/share/thermald.bundle/Contents/Resources/ngoth6.pl
# /usr/share/thermald.bundle/Contents/Resources/nmin6.pl
# /usr/share/thermald.bundle/Contents/Resources/ngoth5.pl
# /usr/share/thermald.bundle/Contents/Resources/nmin5.pl
# /usr/share/thermald.bundle/Contents/Resources/ngoth10.pl
# /usr/share/thermald.bundle/Contents/Resources/nmin10.pl
# /usr/share/thermald.bundle/Contents/Resources/jisn-v.pl
# /usr/share/thermald.bundle/Contents/Resources/jis-v.pl
# /usr/share/thermald.bundle/Contents/Resources/jis.pl
# /usr/share/thermald.bundle/Contents/Resources/jisn.pl
# /usr/share/thermald.bundle/Contents/Resources/ot2-stixgeneral-italic.pl
# /usr/share/thermald.bundle/Contents/Resources/ot1-stixgeneral-bolditalic.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathcal.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathrm.pl
# /usr/share/thermald.bundle/Contents/Resources/ot1-stixgeneral-bold.pl
# /usr/share/thermald.bundle/Contents/Resources/ot1-stixgeneral.pl
# /usr/share/thermald.bundle/Contents/Resources/ts1-stixgeneral-italic.pl
# /usr/share/thermald.bundle/Contents/Resources/ts1-stixgeneral.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathrm-bold.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathtt.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathit-bold.pl
# /usr/share/thermald.bundle/Contents/Resources/ot2-stixgeneral-bold.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-extra1.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathsf-bold.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathbbit-bold.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathsf.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathscr.pl
# /usr/share/thermald.bundle/Contents/Resources/ot2-stixgeneral.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathbb.pl
# /usr/share/thermald.bundle/Contents/Resources/t1-stixgeneral-italic.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathfrak.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathbb-bold.pl
# /usr/share/thermald.bundle/Contents/Resources/t1-stixgeneral-bolditalic.pl
# /usr/share/thermald.bundle/Contents/Resources/t1-stixgeneral-bold.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-extra2-bold.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathsfit.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathex.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathex-bold.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathsfit-bold.pl
# /usr/share/thermald.bundle/Contents/Resources/ot2-stixgeneral-bolditalic.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathtt-bold.pl
# /usr/share/thermald.bundle/Contents/Resources/ot1-stixgeneral-italic.pl
# /usr/share/thermald.bundle/Contents/Resources/ts1-stixgeneral-bold.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-extra3-bold.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathscr-bold.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathfrak-bold.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathbbit.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-extra2.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-extra1-bold.pl
# /usr/share/thermald.bundle/Contents/Resources/t1-stixgeneral.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathcal-bold.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-mathit.pl
# /usr/share/thermald.bundle/Contents/Resources/stix-extra3.pl
# /usr/share/thermald.bundle/Contents/Resources/ts1-stixgeneral-bolditalic.pl
# /usr/share/thermald.bundle/Contents/Resources/config.pl
# /usr/share/thermald.bundle/Contents/Resources/ptex2pdf-tlpost.pl
# /usr/share/thermald.bundle/Contents/Resources/dvipdfmx.pl
# /usr/share/thermald.bundle/Contents/Resources/xetex.pl
# /usr/share/thermald.bundle/Contents/Resources/install-menu-perltk.pl
# /usr/share/thermald.bundle/Contents/Resources/install-menu-wizard.pl
# /usr/share/thermald.bundle/Contents/Resources/install-menu-text.pl
# /usr/share/thermald.bundle/Contents/Resources/ctan-mirrors.pl
# /usr/share/thermald.bundle/Contents/Resources/trans.pl
# /usr/share/thermald.bundle/Contents/Resources/efm_perl.pl
# /usr/share/thermald.bundle/Contents/Resources/efm_filter.pl
# /usr/share/thermald.bundle/Contents/Resources/shtags.pl
# /usr/share/thermald.bundle/Contents/Resources/pltags.pl
# /usr/share/thermald.bundle/Contents/Resources/tutor.pl
# /usr/share/thermald.bundle/Contents/Resources/vim2html.pl
# /usr/share/thermald.bundle/Contents/Resources/merger.pl
# /usr/share/thermald.bundle/Contents/Resources/snmp_perl_trapd.pl

# %% [markdown]
# **Problem 4**: Write a function *hangman* that allows the user to play hangman. It should prompt the user to guess and print to the screen feedback as needed.  The program should randomly select a word and, at each step, indicate to the user all relevant information, e.g. which letters have been guessed (correct and incorrectly) and the number of guesses remaining.  The game should end when the word is completed or the player runs out of guesses (after 6 incorrect guesses).

# %%
from nltk.corpus import words
from nltk.corpus import wordnet
import random as r
import sys

import nltk.data
nltk.data.path.append("/common/golfclass/fgolf/nltk_data/") ## tell nltk where to find the data

def hangman():
    syns = []
    while len(syns) == 0:
        word = r.choice(words.words()).lower() ## get a random word
        word_guessed = ['_']*len(word)
        guessed = []
        syns = wordnet.synsets(str(word)) ## get definition of the word chosen above

    print(' '.join(word_guessed))
    print('{} letters'.format(len(word)))

    nguesses_max = 6
    nguesses = 0
    while nguesses < nguesses_max: ## only run game until nguesses_max incorrect guesses
        letter = str(input('\nEnter a letter: ')).lower() ## get input from user
        while letter in guessed or not letter.isalpha(): ## check if the input is valid (letter, not already guessed)
            if not letter.isalpha():
                print('The input is not a letter.')
            else:
                print('The letter ', letter, ' was already guessed.')
            letter = str(input('\nEnter a letter: ')).lower()
        guessed.append(letter) ## store the guessed letter
        guessed.sort() ## sort them so its easy for the player
        if letter not in word:
            nguesses += 1
            print('The word does not contain the letter \'{}\'.'.format(letter))
            print('Letters guessed: {}'.format(guessed))
            print('{} guesses remaining: \t \033[1m{}\033[0m'.format(nguesses_max-nguesses,' '.join(word_guessed)))
        else:
            location = -1
            while True:  ## correctly guessed a letter
                location = word.find(letter,location+1) ## find which letter(s) match the one we guessed
                if location == -1: break
                word_guessed[location] = letter
            if '_' not in word_guessed:
                print('\nCongratulations!\nYou guessed the word \'{}\' in {} tries.'.format(word,nguesses))
                print('meaning: {}'.format(syns[0].definition()))
                break
            else:
                print('The word contains the letter \'{}\':\t \033[1m{}\033[0m'.format(letter,' '.join(word_guessed)))
                print('{} guesses remaining.'.format(nguesses_max-nguesses))
        if nguesses == nguesses_max:
                print('\nYou ran out of guesses.')
                print('The word was: {}'.format(word))
                print('meaning: {}'.format(syns[0].definition()))
    return

# %%
hangman()
# Out:
# _ _ _ _ _ _ _ _ _ _
# 10 letters
#
# Enter a letter: r
# The word contains the letter 'r':	 _ r _ _ _ _ _ _ _ _
# 6 guesses remaining.
#
# Enter a letter: e
# The word does not contain the letter 'e'.
# Letters guessed: ['e', 'r']
# 5 guesses remaining: 	 _ r _ _ _ _ _ _ _ _
#
# Enter a letter: a
# The word contains the letter 'a':	 _ r _ _ _ a _ _ _ _
# 5 guesses remaining.
#
# Enter a letter: n
# The word contains the letter 'n':	 _ r _ _ _ a _ _ _ n
# 5 guesses remaining.
#
# Enter a letter: i
# The word contains the letter 'i':	 _ r _ i _ a _ i _ n
# 5 guesses remaining.
#
# Enter a letter: o
# The word contains the letter 'o':	 _ r _ i _ a _ i o n
# 5 guesses remaining.
#
# Enter a letter: t
# The word contains the letter 't':	 _ r t i _ a t i o n
# 5 guesses remaining.
#
# Enter a letter: u
# The word contains the letter 'u':	 u r t i _ a t i o n
# 5 guesses remaining.
#
# Enter a letter: z
# The word does not contain the letter 'z'.
# Letters guessed: ['a', 'e', 'i', 'n', 'o', 'r', 't', 'u', 'z']
# 4 guesses remaining: 	 u r t i _ a t i o n
#
# Enter a letter: s
# The word does not contain the letter 's'.
# Letters guessed: ['a', 'e', 'i', 'n', 'o', 'r', 's', 't', 'u', 'z']
# 3 guesses remaining: 	 u r t i _ a t i o n
#
# Enter a letter: b
# The word does not contain the letter 'b'.
# Letters guessed: ['a', 'b', 'e', 'i', 'n', 'o', 'r', 's', 't', 'u', 'z']
# 2 guesses remaining: 	 u r t i _ a t i o n
#
# Enter a letter: c
#
# Congratulations!
# You guessed the word 'urtication' in 4 tries.
# meaning: an itchy skin eruption characterized by weals with pale interiors and well-defined red margins; usually the result of an allergic response to insect bites or food or drugs
